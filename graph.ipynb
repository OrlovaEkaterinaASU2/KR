# %%
from graphviz import Digraph

# %%
dot = Digraph(comment='Map')
dot.node('A', 'Аден',pos="12.789585,45.028504('!')?")
dot.node('B', 'Гонконг',pos="22.34921555, 114.185797810004('!')?")
dot.node('C', 'Индия',pos="22.3511148, 78.6677428('!')?")
dot.node('D', 'Калькутта',pos="22.5677459, 88.3476023('!')?")
dot.node('E', 'Гонконг',pos="22.34921555, 114.185797810004('!')?")
dot.node('F', 'Шанхай',pos="31.2252985, 121.4890497('!')?")
dot.node('G', 'Иокогама',pos="35.444991, 139.636768('!')?")
dot.node('H', 'Нью-йорк',pos="40.7127281, -74.0060152('!')?")
dot.node('I', 'Ливерпуль',pos="53.407154, -2.991665('!')?")
dot.node('J', 'Лондон',pos="51.5073219, -0.1276474('!')?")
dot.edges(['JA','AB','BC','CD','DE','EF','FG','GH','HI','IJ'])
dot

# %%
dot = Digraph(comment='Map')
dot.node('Аден',pos="12.789585!, 45.028504!")
dot.node('Гонконг',pos="22.34921555!, 114.185797810004!")
dot.node('Индия',pos="22.3511148!, 78.6677428!")
dot

# %%
# Out:
#   File "<ipython-input-75-e85c1f73596e>", line 1
#     digraph g {
#             ^
# SyntaxError: invalid syntax
